# %%
#!pip install transformers datasets accelerate
import transformers
print(transformers.__version__)
# Out:
# 5.7.0

# %%
import torch
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    Trainer,
    TrainingArguments,
    DataCollatorForLanguageModeling,
    pipeline
)
from datasets import load_dataset
from peft import LoraConfig, get_peft_model

# %%
# 3️⃣ Model & Tokenizer paths
model_path = "/workspace/work/Meta-Llama-3-8B"  # Path inside Docker
dataset_path = "/workspace/work/clean_150k.jsonl"    # Your JSONL file
output_dir = "/workspace/work/Meta_Llama_finetuned"   # Save fine-tuned model here

# %%
# Use the correct variable 'model_path' defined in Cell 3
tokenizer = AutoTokenizer.from_pretrained(model_path, local_files_only=True)

if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

# Load the model directly to the GPU
model = AutoModelForCausalLM.from_pretrained(
    model_path,                # Fixed variable name
    torch_dtype=torch.float16,
    device_map=None            # We will move it manually to avoid 'meta' device bugs
).to("cuda")

# This is crucial for saving memory during training
model.gradient_checkpointing_enable()

# Verify the device - it should say 'cuda:0'
print(f"Model is on device: {next(model.parameters()).device}")
# Out:
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# Model is on device: cuda:0

# %%
from transformers import BitsAndBytesConfig

quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
)

model = AutoModelForCausalLM.from_pretrained(
    model_path,
    quantization_config=quant_config, # This shrinks the model from 15GB to ~5GB
    device_map={"": 0}
)
# Out:
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]

# %%
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training

# 1. Setup the LoRA config
config = LoraConfig(
    r=16, 
    lora_alpha=32,
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj"], # Targets specific layers
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)

# 2. Wrap the model
model = get_peft_model(model, config)

# 3. Important: Verify only ~1-2% of params are trainable
model.print_trainable_parameters()
# Out:
# trainable params: 13,631,488 || all params: 8,043,892,736 || trainable%: 0.1695

# %%
dataset = load_dataset("json", data_files=dataset_path)["train"]
dataset = dataset.train_test_split(train_size=0.3)

# Tokenization function
def tokenize_fn(examples):
    input_ids_list = []
    attention_masks = []
    labels_list = []

    for instruction, response in zip(examples["instruction"], examples["response"]):
        prompt = f"Instruction: {instruction}\nResponse:"
        full_text = f"{prompt} {response}{tokenizer.eos_token}"

        # Tokenize full text
        tokenized = tokenizer(
            full_text,
            truncation=True,
            padding="max_length",   # important for stable masking
            max_length=512
        )

        # Tokenize prompt only (to know where to mask)
        prompt_ids = tokenizer(
            prompt,
            truncation=True,
            max_length=512
        )["input_ids"]

        labels = tokenized["input_ids"].copy()

        # 🔴 MASK instruction part
        labels[:len(prompt_ids)] = [-100] * len(prompt_ids)

        input_ids_list.append(tokenized["input_ids"])
        attention_masks.append(tokenized["attention_mask"])
        labels_list.append(labels)

    return {
        "input_ids": input_ids_list,
        "attention_mask": attention_masks,
        "labels": labels_list,
    }

tokenized_dataset = dataset.map(tokenize_fn, batched=True)
tokenized_dataset = tokenized_dataset.remove_columns(["instruction", "response"])
tokenized_dataset.set_format("torch")
# Out:
# Map:   0%|          | 0/45000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/105000 [00:00<?, ? examples/s]

# %%
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False  # causal LM
)

# %%
training_args = TrainingArguments(
    output_dir=output_dir,
    per_device_train_batch_size=1,
    gradient_accumulation_steps=16,
    learning_rate=2e-4,
    weight_decay=0.01,
    lr_scheduler_type="cosine",
    num_train_epochs=0.5,
    logging_steps=1,
    save_steps=500,
    fp16=True,  # use if GPU supports, optional
    optim="paged_adamw_8bit",
    gradient_checkpointing=True,       # RE-ENABLE THIS
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["test"],
    data_collator=data_collator
)

# %%
trainer.train()
trainer.save_model(output_dir)
# Out:
#     <div>
#
#       <progress value='58' max='1407' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  58/1407 24:08 < 9:41:29, 0.04 it/s, Epoch 0.02/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.454294</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.505445</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.378021</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.429089</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.341272</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.302963</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.361594</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.201688</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.420363</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.481020</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>2.232324</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>2.355767</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>2.209579</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>2.420402</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>2.265172</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>2.283854</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>2.193931</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>2.334636</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>2.201078</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.558192</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>2.415818</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>2.192036</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>2.237996</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.946006</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>2.137445</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>2.427294</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>2.244459</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>2.046299</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>2.284234</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>2.309503</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>2.219675</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>2.144049</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>2.325285</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>2.196676</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>2.145818</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>2.248125</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>2.360452</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>2.136332</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>2.254490</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>2.385585</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>2.274002</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>2.223140</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>2.120357</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>2.201441</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>2.408227</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>2.284907</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>2.214704</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1.870543</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>2.224949</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>2.208568</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>2.213732</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>1.938476</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>2.248163</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>2.380700</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>2.142148</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>2.290546</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 trainer.train()
#       2 trainer.save_model(output_dir)
#
# File /opt/venv/lib/python3.12/site-packages/transformers/trainer.py:1427, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1425 ctx = suppress_progress_bars() if args.push_to_hub else contextlib.nullcontext()
#    1426 with ctx:
# -> 1427     return inner_training_loop(
#    1428         args=args,
#    1429         resume_from_checkpoint=resume_from_checkpoint,
#    1430         trial=trial,
#    1431         ignore_keys_for_eval=ignore_keys_for_eval,
#    1432     )
#
# File /opt/venv/lib/python3.12/site-packages/transformers/trainer.py:1509, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1507 for epoch in range(epochs_trained, num_train_epochs):
#    1508     self.control = self.callback_handler.on_epoch_begin(self.args, self.state, self.control)
# -> 1509     self._run_epoch(
#    1510         model=model,
#    1511         epoch=epoch,
#    1512         train_dataloader=train_dataloader,
#    1513         steps_in_epoch=steps_in_epoch,
#    1514         num_update_steps_per_epoch=num_update_steps_per_epoch,
#    1515         trial=trial,
#    1516         ignore_keys_for_eval=ignore_keys_for_eval,
#    1517         start_time=start_time,
#    1518         resume_from_checkpoint=resume_from_checkpoint,
#    1519         epochs_trained=epochs_trained,
#    1520         steps_trained_in_current_epoch=steps_trained_in_current_epoch,
#    1521     )
#    1522     if self.control.should_training_stop:
#    1523         break
#
# File /opt/venv/lib/python3.12/site-packages/transformers/trainer.py:1737, in Trainer._run_epoch(self, model, epoch, train_dataloader, steps_in_epoch, num_update_steps_per_epoch, trial, ignore_keys_for_eval, start_time, resume_from_checkpoint, epochs_trained, steps_trained_in_current_epoch)
#    1735     sync_context = functools.partial(self.accelerator.no_sync, model=model)
#    1736 with sync_context():
# -> 1737     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    1739 if (
#    1740     self.args.logging_nan_inf_filter
#    1741     and not is_torch_xla_available()
#    1742     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    1743 ):
#    1744     # if loss is nan or inf simply add the average of previous logged losses
#    1745     self._tr_loss += self._tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File /opt/venv/lib/python3.12/site-packages/transformers/trainer.py:1937, in Trainer.training_step(***failed resolving arguments***)
#    1934 if self.accelerator.distributed_type == DistributedType.DEEPSPEED:
#    1935     kwargs["scale_wrt_gas"] = False
# -> 1937 self.accelerator.backward(loss, **kwargs)
#    1939 return loss.detach()
#
# File /opt/venv/lib/python3.12/site-packages/accelerate/accelerator.py:2848, in Accelerator.backward(self, loss, **kwargs)
#    2846     return
#    2847 elif self.scaler is not None:
# -> 2848     self.scaler.scale(loss).backward(**kwargs)
#    2849 elif learning_rate is not None and self.has_lomo_optimizer:
#    2850     self.lomo_backward(loss, learning_rate)
#
# File /opt/venv/lib/python3.12/site-packages/torch/_tensor.py:630, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     620 if has_torch_function_unary(self):
#     621     return handle_torch_function(
#     622         Tensor.backward,
#     623         (self,),
#    (...)    628         inputs=inputs,
#     629     )
# --> 630 torch.autograd.backward(
#     631     self, gradient, retain_graph, create_graph, inputs=inputs
#     632 )
#
# File /opt/venv/lib/python3.12/site-packages/torch/autograd/__init__.py:364, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     359     retain_graph = create_graph
#     361 # The reason we repeat the same comment below is that
#     362 # some Python versions print out the first line of a multi-line function
#     363 # calls in the traceback and some print out the last line
# --> 364 _engine_run_backward(
#     365     tensors,
#     366     grad_tensors_,
#     367     retain_graph,
#     368     create_graph,
#     369     inputs_tuple,
#     370     allow_unreachable=True,
#     371     accumulate_grad=True,
#     372 )
#
# File /opt/venv/lib/python3.12/site-packages/torch/autograd/graph.py:865, in _engine_run_backward(t_outputs, *args, **kwargs)
#     863     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     864 try:
# --> 865     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     866         t_outputs, *args, **kwargs
#     867     )  # Calls into the C++ engine to run the backward pass
#     868 finally:
#     869     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
pipe = pipeline(
    "text-generation",
    model=output_dir,
    tokenizer=tokenizer
)

# %%
prompt = "Instruction: How can I make focus follow the mouse cursor?\nResponse:"
output = pipe(prompt, max_new_tokens=256, temperature=0.7, top_p=0.9, do_sample=True)
print(output[0]["generated_text"])
